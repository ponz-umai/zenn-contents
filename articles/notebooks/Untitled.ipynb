# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import sympy

# %%
from sympy import var, cos, sin
from sympy.plotting import plot3d
from mpl_toolkits.mplot3d import Axes3D

# %%
plt.rcParams['figure.figsize'] = 8, 8

# %%
var('x y')
# Out:
# (x, y)

# %%
z = cos(2*np.pi*(sympy.sqrt(2)*y)/2 )*cos(2*np.pi*(x-y)/2)

# %%
p =  plot3d(z,(x,0,4),(y,0,4))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
z2 = cos(2*np.pi*/2  ) + cos(2*np.pi*y/2  )

# %%
p = plot3d(z2,(x,-2,2),(y,-2,2))

# %%
ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)

# %%
z =  cos(2*np.pi*(x-y)/2  )

# %%
p =  plot3d(z,(x,-4,4),(y,-4,4))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fig = plt.figure()

# %%
ax = fig.add_subplot(projection = '3d')

# %%
data = np.linspace(-3*np.pi,3*np.pi,50)
x, y = np.meshgrid(data,data)

# %%
z = np.cos(2*np.pi*(np.sqrt(2)*y)/2 )*np.cos(2*np.pi*(x-y)/2)

# %%
ax.plot_surface(x,y,z,color = "darkblue")

# %%
plt.show()

# %%
# %matplotlib notebook

# %%
plt.show()

# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-1, 4.5, 0.005)
y = np.arange(-1, 4.5, 0.005)
X, Y = np.meshgrid(x, y)
Z = np.cos(2*np.pi*(np.sqrt(2)*Y)/2 )*np.cos(2*np.pi*(X-Y)/2)

fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X,Y,Z)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
x = np.arange(0, 2.5, 0.005)
y = np.arange(0, 2.5, 0.005)
X, Y = np.meshgrid(x, y)
Z = np.sin(2*np.pi*(np.sqrt(2)*Y)/np.sqrt(2) )*np.sin(2*np.pi*(X-Y))
cont = plt.contour(X, Y, Z)
plt.rcParams['figure.figsize'] = 2, 2
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
# %matplotlib notebook
x = np.arange(0, 2.5, 0.005)
y = np.arange(0, 2.5, 0.005)
X, Y = np.meshgrid(x, y)
Z = np.sin(2*np.pi*2*(np.sqrt(2)*Y)/np.sqrt(2) )*np.sin(2*np.pi*(X-Y))
cont = plt.contour(X, Y, Z)
plt.rcParams['figure.figsize'] = 4, 4
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-1, 4.5, 0.005)
y = np.arange(-1, 4.5, 0.005)
X, Y = np.meshgrid(x, y)
Z = np.cos(2*np.pi*(X-Y)/2)

fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X,Y,Z)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">
